# %%
import pandas as pd
training_set = pd.read_csv('../dataset/training_set.csv')
training_set_metadata = pd.read_csv('../dataset/training_set_metadata.csv')

# %%
training_set.head()
# Out:
#    object_id         mjd  passband        flux   flux_err  detected
# 0        615  59750.4229         2 -544.810303   3.622952         1
# 1        615  59750.4306         1 -816.434326   5.553370         1
# 2        615  59750.4383         3 -471.385529   3.801213         1
# 3        615  59750.4450         4 -388.984985  11.395031         1
# 4        615  59752.4070         2 -681.858887   4.041204         1

# %%
training_set['mjd'] = training_set.groupby(['object_id', 'passband'])["mjd"].transform(lambda x: (x - x.min()))

# %%
train_by_object_and_passband = training_set.groupby(['object_id', 'passband'])

# %%
train_by_object_and_passband.mean()
# Out:
#                            mjd         flux   flux_err  detected
# object_id passband
# 615       0         459.787530    -3.254554   3.823448  0.857143
#           1         425.323655  -385.699911   5.029014  0.965517
#           2         425.323648  -134.146566   3.380299  0.982759
#           3         425.323647  -121.103501   3.340116  0.982759
#           4         425.327940   -55.954592   3.798761  0.982759
#           5         430.802351   -47.449847   7.636021  0.912281
# 713       0         464.676470    -2.720398   2.331400  0.142857
#           1         416.714655    -1.019804   1.416982  0.267857
#           2         416.714271    -0.794238   1.192936  0.267857
#           3         416.714952    -0.986966   1.640155  0.267857
#           4         416.715682    -0.900262   2.268854  0.089286
#           5         416.716118    -1.794175   5.314447  0.000000
# 730       0         429.427419    -0.048080   2.057984  0.000000
# ...

# %%
training_set.head()
# Out:
#    object_id     mjd  passband        flux   flux_err  detected
# 0        615  0.0000         2 -544.810303   3.622952         1
# 1        615  0.0000         1 -816.434326   5.553370         1
# 2        615  0.0000         3 -471.385529   3.801213         1
# 3        615  0.0000         4 -388.984985  11.395031         1
# 4        615  1.9841         2 -681.858887   4.041204         1

# %%
training_set.tail()
# Out:
#          object_id       mjd  passband       flux   flux_err  detected
# 1421700  130779836  833.6750         4 -39.881969  46.477093         0
# 1421701  130779836  806.8968         1  14.894439  18.947685         0
# 1421702  130779836  855.6906         5  30.593130  50.695290         0
# 1421703  130779836  863.6886         4 -23.471439  44.819859         0
# 1421704  130779836  770.8949         0 -41.214264  51.665123         0

# %%
training_set.to_csv('training_set_mjd_reset_by_passband.csv')
